# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/sales_data.csv')
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 0     236670            Wired Headphones                2      11.99
# 1     236671  Bose SoundSport Headphones                1      99.99
# 2     236672                      iPhone                1      700.0
# 3     236673       AA Batteries (4-pack)                2       3.84
# 4     236674       AA Batteries (4-pack)                2       3.84
# ..       ...                         ...              ...        ...
# 796   237436        USB-C Charging Cable                1      11.95
# 797   237437      AAA Batteries (4-pack)                2       2.99
# 798   237438      27in 4K Gaming Monitor                1     389.99
# 799   237439  Bose SoundSport Headphones                1      99.99
# 800   237440      AAA Batteries (4-pack)                1       2.99
#
#          Order Date                      Purchase Address
# 0    08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# ...
